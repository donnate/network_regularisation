# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from skest import *
import scipy
import time
from signals import *
import matplotlib as mpl

mpl.rcParams['mathtext.fontset'] = 'cm'

# %% [markdown]
# #### different shapes

# %%
p = 225
a = 15

# %%
xs = np.linspace(1, a+1, a)
ys = np.linspace(1, a+1, a)
xs, ys = np.meshgrid(xs, ys)

# %%
from matplotlib.ticker import AutoMinorLocator, MultipleLocator

# %% [markdown]
# ### a

# %%
beta_star1 = smooth_2d(a,3.9, 0.1, 3, 5)
xs = np.linspace(1, a+1, a)
ys = np.linspace(1, a+1, a)
xs, ys = np.meshgrid(xs, ys)
zs_surface = beta_star1.reshape(a,a)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xs, ys, zs_surface, rstride=1, cstride=1, cmap='viridis', edgecolor = 'gray', linewidth = 0.5)

ax.view_init(45, 25)

ax.xaxis.set_major_locator(MultipleLocator(5))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.xaxis._axinfo["grid"]['linestyle'] = ":"
ax.yaxis._axinfo["grid"]['linestyle'] = ":"
ax.zaxis._axinfo["grid"]['linewidth'] = 0.5

ax.tick_params(axis = 'both', which = 'major', labelsize = 13)
ax.set_ylabel('column index j', size = 13)
ax.set_xlabel('row index i', size = 13)
ax.zaxis.set_rotate_label(False)
ax.set_zlabel(r'$\beta_{i,j}^*$', rotation = 0, size = 15)
plt.savefig('141a.jpg', bbox_inches='tight', dpi = 600)

# %% [markdown]
# ### b

# %%
beta_star2 = smooth_2d(a,3.5, 2.5, 3, 5)
xs = np.linspace(1, a+1, a)
ys = np.linspace(1, a+1, a)
xs, ys = np.meshgrid(xs, ys)
zs_surface = beta_star2.reshape(a,a)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xs, ys, zs_surface, rstride=1, cstride=1, cmap='viridis', edgecolor = 'gray', linewidth = 0.5)

ax.view_init(45, 25)
ax.xaxis.set_major_locator(MultipleLocator(5))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.xaxis._axinfo["grid"]['linestyle'] = ":"
ax.yaxis._axinfo["grid"]['linestyle'] = ":"
ax.zaxis._axinfo["grid"]['linewidth'] = 0.5

ax.tick_params(axis = 'both', which = 'major', labelsize = 13)
ax.set_ylabel('column index j', size = 13)
ax.set_xlabel('row index i', size = 13)
ax.zaxis.set_rotate_label(False)
ax.set_zlabel(r'$\beta_{i,j}^*$', rotation = 0, size = 15)
plt.savefig('141b.jpg', bbox_inches='tight', dpi = 600)

# %% [markdown]
# ### c

# %%
beta_star3 = smooth_2d(a, 3, 4, 3, 5)

zs_surface = beta_star3.reshape(a,a)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xs, ys, zs_surface, rstride=1, cstride=1, cmap='viridis', edgecolor = 'gray', linewidth = 0.5)

ax.view_init(45, 25)
ax.xaxis.set_major_locator(MultipleLocator(5))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.xaxis._axinfo["grid"]['linestyle'] = ":"
ax.yaxis._axinfo["grid"]['linestyle'] = ":"
ax.zaxis._axinfo["grid"]['linewidth'] = 0.5
ax.tick_params(axis = 'both', which = 'major', labelsize = 13)
ax.set_ylabel('column index j', size = 13)
ax.set_xlabel('row index i', size = 13)
ax.zaxis.set_rotate_label(False)
ax.set_zlabel(r'$\beta_{i,j}^*$', rotation = 0, size = 15)
plt.savefig('141c.jpg', bbox_inches='tight', dpi = 600)

# %% [markdown]
# ## d

# %%
beta_star4 = smooth_2d(a,2, 5.5, 3, 5)
xs = np.linspace(1, a+1, a)
ys = np.linspace(1, a+1, a)
xs, ys = np.meshgrid(xs, ys)
zs_surface = beta_star4.reshape(a,a)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xs, ys, zs_surface, rstride=1, cstride=1, cmap='viridis', edgecolor = 'gray', linewidth = 0.5)

ax.view_init(45, 25)
ax.xaxis.set_major_locator(MultipleLocator(5))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.xaxis._axinfo["grid"]['linestyle'] = ":"
ax.yaxis._axinfo["grid"]['linestyle'] = ":"
ax.zaxis._axinfo["grid"]['linewidth'] = 0.5

ax.tick_params(axis = 'both', which = 'major', labelsize = 13)
ax.set_ylabel('column index j', size = 13)
ax.set_xlabel('row index i', size = 13)
ax.zaxis.set_rotate_label(False)
ax.set_zlabel(r'$\beta_{i,j}^*$', rotation = 0, size = 15)
plt.savefig('141d.jpg', bbox_inches='tight', dpi = 600)

# %% [markdown]
# ## e

# %%
beta_star5 = smooth_2d(a,1, 7, 3, 5)
xs = np.linspace(1, a+1, a)
ys = np.linspace(1, a+1, a)
xs, ys = np.meshgrid(xs, ys)
zs_surface = beta_star5.reshape(a,a)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xs, ys, zs_surface, rstride=1, cstride=1, cmap='viridis', edgecolor = 'gray', linewidth = 0.5)

ax.view_init(45, 25)

ax.xaxis.set_major_locator(MultipleLocator(5))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.xaxis._axinfo["grid"]['linestyle'] = ":"
ax.yaxis._axinfo["grid"]['linestyle'] = ":"
ax.zaxis._axinfo["grid"]['linewidth'] = 0.5

ax.tick_params(axis = 'both', which = 'major', labelsize = 13)
ax.set_ylabel('column index j', size = 13)
ax.set_xlabel('row index i', size = 13)
ax.zaxis.set_rotate_label(False)
ax.set_zlabel(r'$\beta_{i,j}^*$', rotation = 0, size = 15)
plt.savefig('141e.jpg', bbox_inches='tight', dpi = 600)

# %% [markdown]
# ### f

# %%
beta_star6 = smooth_2d(a,0.001, 9, 3, 5)
xs = np.linspace(1, a+1, a)
ys = np.linspace(1, a+1, a)
xs, ys = np.meshgrid(xs, ys)
zs_surface = beta_star6.reshape(a,a)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xs, ys, zs_surface, rstride=1, cstride=1, cmap='viridis', edgecolor = 'gray', linewidth = 0.5)

ax.view_init(45, 25)
ax.xaxis.set_major_locator(MultipleLocator(5))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.xaxis._axinfo["grid"]['linestyle'] = ":"
ax.yaxis._axinfo["grid"]['linestyle'] = ":"
ax.zaxis._axinfo["grid"]['linewidth'] = 0.5

ax.tick_params(axis = 'both', which = 'major', labelsize = 13)
ax.set_ylabel('column index j', size = 13)
ax.set_xlabel('row index i', size = 13)
ax.zaxis.set_rotate_label(False)
ax.set_zlabel(r'$\beta_{i,j}^*$', rotation = 0, size = 15)
plt.savefig('141f.jpg', bbox_inches='tight', dpi = 600)

# %% [markdown]
# ### a slope l = 1

# %%
D = grid_incidence(a)
G = nx.grid_graph(dim = (a,a))
Psi = cor_from_G(G, 0.5)

# %%
sigma = 3

# %%
n = 150

# %%
X, y = gauss_sample(n, p, beta_star1.flatten(), Psi, sigma)

# %%
print(naive_cv(SL, X, y, D))
# Out:
# ({'l1': 0, 'l2': 0.25}, 71.2251136302948)

# %%
print(naive_cv(OUR, X,y, D))
print(naive_cv(FL, X, y, D))
print(naive_cv(SL, X, y, D))
# Out:
# ({'l1': 25, 'l2': 0}, 77.09395623207092)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-293-04041db6dabb> in <module>
#       1 print(naive_cv(OUR, X,y, D))
# ----> 2 print(naive_cv(FL, X, y, D))
#       3 print(naive_cv(SL, X, y, D))
#
# ~\Desktop\running time\signals.py in naive_cv(clf, X, y, D, n_cv)
#      53     gd_sr = GridSearchCV(clf(0,0,D), param_grid=grid1,scoring = 'neg_mean_squared_error',cv=n_cv, n_jobs=-1)
#      54     start_time = time.time()
# ---> 55     result = gd_sr.fit(X,y)
#      56     return result.best_params_, time.time() - start_time
#      57
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
# ...

# %%
beta_star1 = beta_star1.flatten()

# %%
def trial1():
    X, y = gauss_sample(n, p, beta_star1, Psi, sigma)
    clf1 = FL(3, 25, D).fit(X, y)
    clf2 = SL(0, 0.25, D).fit(X,y)
    clf3 = OUR(25, 0, D).fit(X,y)
    return [c.l2_risk(beta_star1) for c in [clf1, clf2, clf3]]

# %%
from joblib import Parallel, delayed
import multiprocessing

# %%
l2s = Parallel(n_jobs=8)(delayed(trial1)() for i in range(500))

# %%
def trial3():
    X, y = gauss_sample(n, p, beta_star1, Psi, sigma)
    clf1 = FL(3, 25, D).fit(X, y)
    clf2 = SL(0, 0.25, D).fit(X,y)
    clf3 = OUR(25, 0, D).fit(X,y)
    X2, y2 = gauss_sample(n, p, beta_star1, Psi, sigma)
    return [-c.score(X2, X2@beta_star1) for c in [clf1, clf2, clf3]]

# %%
preds = Parallel(n_jobs=8)(delayed(trial3)() for i in range(500))

# %%
ap1 = [l[0] for l in preds]
ap2 = [l[1] for l in preds]
ap3 = [l[2] for l in preds]

# %%
plt.boxplot([ap1,ap2,ap3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2463f2d8400>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2463c937070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24650146760>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2463c388f70>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2463c494f40>,
# ...
#  'means': []}

# %%
ar1 = [l[0] for l in l2s]
ar2 = [l[1] for l in l2s]
ar3 = [l[2] for l in l2s]

# %%
plt.boxplot([ar1,ar2,ar3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2463f0ab850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2463c3d9d00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2463f0abe80>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2463f5483d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2463f548130>,
# ...
#  'means': []}

# %% [markdown]
# ### b slope l = 5

# %%
plt.plot(beta_star6.reshape((a,a)))

# %%
plt.plot(beta_star5.reshape((a,a)))

# %%
beta_star2 = beta_star2.flatten()

# %%
X, y = gauss_sample(n, p, beta_star2, Psi, sigma)

# %%
print(naive_cv(OUR, X,y, D))
# Out:
# ({'l1': 25, 'l2': 3}, 74.43597078323364)

# %%
print(naive_cv(OUR, X,y, D))
print(naive_cv(FL, X, y, D))
print(naive_cv(SL, X, y, D))
# Out:
# ({'l1': 20, 'l2': 0.1}, 76.05929064750671)
# ({'l1': 0, 'l2': 20}, 55.178534746170044)
# ({'l1': 0.001, 'l2': 7.5}, 69.0874879360199)

# %%
def trial1():
    X, y = gauss_sample(n, p, beta_star2, Psi, sigma)
    clf1 = FL(0, 20, D).fit(X, y)
    clf2 = SL(0.001, 7.5, D).fit(X,y)
    clf3 = OUR(25, 3, D).fit(X,y)
    return [c.l2_risk(beta_star2) for c in [clf1, clf2, clf3]]

# %%
def trial3():
    X, y = gauss_sample(n, p, beta_star2, Psi, sigma)
    clf1 = FL(0, 20, D).fit(X, y)
    clf2 = SL(0.001, 7.5, D).fit(X,y)
    clf3 = OUR(25, 3, D).fit(X,y)
    X2, y2 = gauss_sample(n, p, beta_star2, Psi, sigma)
    return [-c.score(X2, X2@beta_star2) for c in [clf1, clf2, clf3]]

# %%
l2s = Parallel(n_jobs=8)(delayed(trial1)() for i in range(500))

# %%
preds = Parallel(n_jobs=8)(delayed(trial3)() for i in range(500))

# %%
bp1 = [l[0] for l in preds]
bp2 = [l[1] for l in preds]
bp3 = [l[2] for l in preds]

# %%
br1 = [l[0] for l in l2s]
br2 = [l[1] for l in l2s]
br3 = [l[2] for l in l2s]

# %%
plt.boxplot([br1,br2,br3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2463ca64130>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2463ca59f40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2463cac2670>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2463ca77880>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2463ca77730>,
# ...
#  'means': []}

# %%
plt.boxplot([bp1,bp2,bp3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2463ca7d1f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2463ca7d8b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2463ca7fe20>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2463ca7df70>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2463cb18310>,
# ...
#  'means': []}

# %% [markdown]
# ### c slope l = 10

# %%
beta_star3 = beta_star3.flatten()

# %%
X, y = gauss_sample(n, p, beta_star3, Psi, sigma)
print(naive_cv_large(OUR, X,y, D))
print(naive_cv_large(FL, X, y, D))
print(naive_cv_large(SL, X, y, D))
# Out:
# ({'l1': 15, 'l2': 7.5}, 72.94092607498169)
# ({'l1': 5, 'l2': 20}, 51.83486032485962)
# ({'l1': 0, 'l2': 15}, 68.28817820549011)

# %%
def trial1():
    X, y = gauss_sample(n, p, beta_star3, Psi, sigma)
    clf1 = FL(5, 20, D).fit(X, y)
    clf2 = SL(0, 15, D).fit(X,y)
    clf3 = OUR(15, 7.5, D).fit(X,y)
    return [c.l2_risk(beta_star3) for c in [clf1, clf2, clf3]]
def trial3():
    X, y = gauss_sample(n, p, beta_star3, Psi, sigma)
    clf1 = FL(5, 20, D).fit(X, y)
    clf2 = SL(0, 15, D).fit(X,y)
    clf3 = OUR(15, 7.5, D).fit(X,y)
    X2, y2 = gauss_sample(n, p, beta_star3, Psi, sigma)
    return [-c.score(X2, X2@beta_star3) for c in [clf1, clf2, clf3]]

# %%
l2s = Parallel(n_jobs=8)(delayed(trial1)() for i in range(500))
preds = Parallel(n_jobs=8)(delayed(trial3)() for i in range(500))
cp1 = [l[0] for l in preds]
cp2 = [l[1] for l in preds]
cp3 = [l[2] for l in preds]
cr1 = [l[0] for l in l2s]
cr2 = [l[1] for l in l2s]
cr3 = [l[2] for l in l2s]

# %%
plt.boxplot([cp1,cp2,cp3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2463c5989d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2464012c910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2463f086430>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x24640139610>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2463f15aa60>,
# ...
#  'means': []}

# %%
plt.boxplot([cr1,cr2,cr3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2463f199a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2463f3af220>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2463f199430>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2463f0d2f40>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2463f0d2cd0>,
# ...
#  'means': []}

# %% [markdown]
# ### d slope l = 15

# %%
beta_star4 = beta_star4.flatten()

# %%
X, y = gauss_sample(n, p, beta_star4, Psi, sigma)
print(naive_cv_large(OUR, X,y, D))
print(naive_cv_large(FL, X, y, D))
print(naive_cv_large(SL, X, y, D))
# Out:
# ({'l1': 5, 'l2': 10}, 72.03501391410828)
# ({'l1': 1, 'l2': 7.5}, 50.20052123069763)
# ({'l1': 0.5, 'l2': 15}, 65.87448596954346)

# %%
def trial1():
    X, y = gauss_sample(n, p, beta_star4, Psi, sigma)
    clf1 = FL(1, 7.5, D).fit(X, y)
    clf2 = SL(0.5, 15, D).fit(X,y)
    clf3 = OUR(5, 10, D).fit(X,y)
    return [c.l2_risk(beta_star4) for c in [clf1, clf2, clf3]]

def trial3():
    X, y = gauss_sample(n, p, beta_star4, Psi, sigma)
    clf1 = FL(1, 7.5, D).fit(X, y)
    clf2 = SL(0.5, 15, D).fit(X,y)
    clf3 = OUR(5, 10, D).fit(X,y)
    X2, y2 = gauss_sample(n, p, beta_star4, Psi, sigma)
    return [-c.score(X2, X2@beta_star4) for c in [clf1, clf2, clf3]]

# %%
l2s = Parallel(n_jobs=8)(delayed(trial1)() for i in range(500))
preds = Parallel(n_jobs=8)(delayed(trial3)() for i in range(500))
dp1 = [l[0] for l in preds]
dp2 = [l[1] for l in preds]
dp3 = [l[2] for l in preds]
dr1 = [l[0] for l in l2s]
dr2 = [l[1] for l in l2s]
dr3 = [l[2] for l in l2s]

# %%
plt.boxplot([dp1,dp2,dp3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2463f3dc400>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2463f0d8430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24640139bb0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x24643a67c70>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2463f46b2e0>,
# ...
#  'means': []}

# %%
plt.boxplot([dr1,dr2,dr3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2463ca30070>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2463ca30730>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24643a5bca0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2463ca30df0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2463ca36190>,
# ...
#  'means': []}

# %% [markdown]
# ### e slope l = 25

# %%
beta_star5 = beta_star5.flatten()

# %%
X, y = gauss_sample(n, p, beta_star5, Psi, sigma)
print(naive_cv_large(OUR, X,y, D))
print(naive_cv_large(FL, X, y, D))
print(naive_cv_large(SL, X, y, D))
# Out:
# ({'l1': 7.5, 'l2': 10}, 70.41061758995056)
# ({'l1': 2, 'l2': 7.5}, 50.16004657745361)
# ({'l1': 2, 'l2': 20}, 67.12587308883667)

# %%
def trial1():
    X, y = gauss_sample(n, p, beta_star5, Psi, sigma)
    clf1 = FL(2, 7.5, D).fit(X, y)
    clf2 = SL(2, 20, D).fit(X,y)
    clf3 = OUR(10, 20, D).fit(X,y)
    return [c.l2_risk(beta_star5) for c in [clf1, clf2, clf3]]

def trial3():
    X, y = gauss_sample(n, p, beta_star5, Psi, sigma)
    clf1 = FL(2, 7.5, D).fit(X, y)
    clf2 = SL(2, 20, D).fit(X,y)
    clf3 = OUR(10, 20, D).fit(X,y)
    X2, y2 = gauss_sample(n, p, beta_star5, Psi, sigma)
    return [-c.score(X2, X2@beta_star5) for c in [clf1, clf2, clf3]]

# %%
l2s = Parallel(n_jobs=8)(delayed(trial1)() for i in range(500))
preds = Parallel(n_jobs=8)(delayed(trial3)() for i in range(500))
ep1 = [l[0] for l in preds]
ep2 = [l[1] for l in preds]
ep3 = [l[2] for l in preds]
er1 = [l[0] for l in l2s]
er2 = [l[1] for l in l2s]
er3 = [l[2] for l in l2s]

# %%
plt.boxplot([ep1,ep2,ep3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2463e0e7c70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2463cb37dc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2463e177520>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2463e1324f0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2463ee4d190>,
# ...
#  'means': []}

# %%
plt.boxplot([er1,er2,er3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24643468d30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2463ed36f70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24643468970>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2463ed36370>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2463ed36be0>,
# ...
#  'means': []}

# %% [markdown]
# ### f slope l = 35

# %%
beta_star6 = beta_star6.flatten()

# %%
X, y = gauss_sample(n, p, beta_star6, Psi, sigma)
print(naive_cv_large(FL, X, y, D))
# Out:
# ({'l1': 0.5, 'l2': 5}, 45.106130838394165)

# %%
print(naive_cv_large(OUR, X,y, D))
print(naive_cv_large(SL, X, y, D))
# Out:
# ({'l1': 0, 'l2': 25}, 78.24088191986084)
# ({'l1': 1, 'l2': 25}, 68.82651472091675)

# %%
def trial1():
    X, y = gauss_sample(n, p, beta_star6, Psi, sigma)
    clf1 = FL(0.5, 5, D).fit(X, y)
    clf2 = SL(1, 25, D).fit(X,y)
    clf3 = OUR(0, 25, D).fit(X,y)
    return [c.l2_risk(beta_star6) for c in [clf1, clf2, clf3]]

def trial3():
    X, y = gauss_sample(n, p, beta_star6, Psi, sigma)
    clf1 = FL(0.5, 5, D).fit(X, y)
    clf2 = SL(1, 25, D).fit(X,y)
    clf3 = OUR(0, 25, D).fit(X,y)
    X2, y2 = gauss_sample(n, p, beta_star6, Psi, sigma)
    return [-c.score(X2, X2@beta_star6) for c in [clf1, clf2, clf3]]

# %%
l2s = Parallel(n_jobs=8)(delayed(trial1)() for i in range(500))
preds = Parallel(n_jobs=8)(delayed(trial3)() for i in range(500))
fp1 = [l[0] for l in preds]
fp2 = [l[1] for l in preds]
fp3 = [l[2] for l in preds]
fr1 = [l[0] for l in l2s]
fr2 = [l[1] for l in l2s]
fr3 = [l[2] for l in l2s]

# %%
plt.boxplot([fp1,fp2,fp3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2463edaf940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2463cc5f4f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2463ed75910>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2463eda2280>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2463e906fd0>,
# ...
#  'means': []}

# %%
plt.boxplot([fr1,fr2,fr3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2463e1026a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2463e164bb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2463e102280>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2463e164e50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2463e164970>,
# ...
#  'means': []}

# %% [markdown]
# # Important: store risk and prediction error

# %%
FL_risk_med = [np.median(r) for r in [ar1, br1, cr1, dr1, er1, fr1]]

# %%
FL_risk_err = [[np.median(r) - np.quantile(r, 0.25) for r in [ar1, br1, cr1, dr1, er1, fr1]], [np.quantile(r, 0.75) - np.median(r) for r in [ar1, br1, cr1, dr1, er1, fr1]]]

# %%
SL_risk_med = [np.median(r) for r in [ar2, br2, cr2, dr2, er2, fr2]]
SL_risk_err = [[np.median(r) - np.quantile(r, 0.25) for r in [ar2, br2, cr2, dr2, er2, fr2]], [np.quantile(r, 0.75) - np.median(r) for r in [ar2, br2, cr2, dr2, er2, fr2]]]

# %%
GEE_risk_med = [np.median(r) for r in [ar3, br3, cr3, dr3, er3, fr3]]
GEE_risk_err = [[np.median(r) - np.quantile(r, 0.25) for r in [ar3, br3, cr3, dr3, er3, fr3]], [np.quantile(r, 0.75) - np.median(r) for r in [ar3, br3, cr3, dr3, er3, fr3]]]

# %%
edge_smoothness = [la.norm(D@b) for b in [beta_star1, beta_star2, beta_star3, beta_star4, beta_star5, beta_star6]]

# %%
L_infty = [la.norm(D.T @ D @b, ord = np.inf) for b in [beta_star1, beta_star2, beta_star3, beta_star4, beta_star5, beta_star6]]

# %%
import matplotlib as mpl

# %%
x1s_ticks = [str(round(l,2)) for l in L_infty]
x2s_ticks = [str(round(e,2)) for e in edge_smoothness]

# %%
mpl.rcParams['mathtext.fontset'] = 'cm'

fig, ax1 = plt.subplots()
ax2 = ax1.twiny()
ax2.set_xlabel(r"$\|\Gamma \beta^*\|_2$", size = 13)
ax1.set_xlabel(r'$\|L \beta^*\|_\infty$', size = 13)
ax1.plot(x1s_ticks,FL_risk_med, color = 'orange')
ax2.errorbar(x2s_ticks, FL_risk_med, yerr = FL_risk_err, capsize = 2, color = 'orange', label = "FL")
ax2.errorbar(x2s_ticks, SL_risk_med, yerr = SL_risk_err, capsize = 2, color = 'red', label = "SL")
ax2.errorbar(x2s_ticks, GEE_risk_med, yerr = GEE_risk_err, capsize = 2, color = 'green', label = "GEN")
ax1.set_ylabel(r'$\| \hat{\beta} - \beta^*\|_2$', size = 14)
plt.legend()
plt.title(r"Adaptivity to smoothness levels: $l_2$ risk", size = 14)
fig.savefig('142a.jpg', bbox_inches='tight', dpi = 600)

# %%
FL_pred_med = [np.median(r) for r in [ap1, bp1, cp1, dp1, ep1, fp1]]
FL_pred_err = [[np.median(r) - np.quantile(r, 0.25) for r in [ap1, bp1, cp1, dp1, ep1, fp1]], [np.quantile(r, 0.75) - np.median(r) for r in [ap1, bp1, cp1, dp1, ep1, fp1]]]

# %%
SL_pred_med = [np.median(r) for r in [ap2, bp2, cp2, dp2, ep2, fp2]]
SL_pred_err = [[np.median(r) - np.quantile(r, 0.25) for r in [ap2, bp2, cp2, dp2, ep2, fp2]], [np.quantile(r, 0.75) - np.median(r) for r in [ap2, bp2, cp2, dp2, ep2, fp2]]]

# %%
GEE_pred_med = [np.median(r) for r in [ap3, bp3, cp3, dp3, ep3, fp3]]
GEE_pred_err = [[np.median(r) - np.quantile(r, 0.25) for r in [ap3, bp3, cp3, dp3, ep3, fp3]], [np.quantile(r, 0.75) - np.median(r) for r in [ap3, bp3, cp3, dp3, ep3, fp3]]]

# %%
mpl.rcParams['mathtext.fontset'] = 'cm'

fig, ax1 = plt.subplots()
ax2 = ax1.twiny()
ax2.set_xlabel(r"$\|\Gamma \beta^*\|_2$", size = 13)
ax1.set_xlabel(r'$\|L \beta^*\|_\infty$', size = 13)
ax1.plot(x1s_ticks,FL_pred_med, color = 'orange')
ax2.errorbar(x2s_ticks, FL_pred_med, yerr = FL_pred_err, capsize = 2, color = 'orange', label = "FL")
ax2.errorbar(x2s_ticks, SL_pred_med, yerr = SL_pred_err, capsize = 2, color = 'red', label = "SL")
ax2.errorbar(x2s_ticks, GEE_pred_med, yerr = GEE_pred_err, capsize = 2, color = 'green', label = "GEN")
ax1.set_ylabel(r'$\frac{1}{n}\| X_{\mathrm{test}}(\hat{\beta} - \beta^*)\|_2^2$', size = 14)
plt.legend()
plt.title("Adaptivity to smoothness levels: MSE", size = 14)
fig.savefig('142b.jpg', bbox_inches='tight', dpi = 600)

# %% [markdown]
# ### shape of reconstruction

# %%
X, y = gauss_sample(n, p, beta_star3, Psi, sigma)
clf1 = FL(5, 20, D).fit(X, y)
clf2 = SL(0, 15, D).fit(X,y)
clf3 = OUR(15, 7.5, D).fit(X,y)

# %%
b1 = clf1.beta.reshape(a,a)

# %%
xs = np.linspace(1, a+1, a)
ys = np.linspace(1, a+1, a)
xs, ys = np.meshgrid(xs, ys)
zs_surface = clf1.beta.reshape(a,a)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xs, ys, zs_surface, rstride=1, cstride=1, cmap='viridis', edgecolor = 'gray', linewidth = 0.5)

ax.view_init(45, 25)

ax.xaxis.set_major_locator(MultipleLocator(5))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.xaxis._axinfo["grid"]['linestyle'] = ":"
ax.yaxis._axinfo["grid"]['linestyle'] = ":"
ax.zaxis._axinfo["grid"]['linewidth'] = 0.5

ax.tick_params(axis = 'both', which = 'major', labelsize = 13)
ax.set_ylabel('column index j', size = 13)
ax.set_xlabel('row index i', size = 13)
ax.zaxis.set_rotate_label(False)
ax.set_zlabel(r'$\hat{\beta}_{i,j}$', rotation = 0, size = 15)
plt.savefig('143a.jpg', bbox_inches='tight', dpi = 600)

# %%
xs = np.linspace(1, a+1, a)
ys = np.linspace(1, a+1, a)
xs, ys = np.meshgrid(xs, ys)
zs_surface = clf2.beta.reshape(a,a)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xs, ys, zs_surface, rstride=1, cstride=1, cmap='viridis', edgecolor = 'gray', linewidth = 0.5)

ax.view_init(45, 25)

ax.xaxis.set_major_locator(MultipleLocator(5))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.xaxis._axinfo["grid"]['linestyle'] = ":"
ax.yaxis._axinfo["grid"]['linestyle'] = ":"
ax.zaxis._axinfo["grid"]['linewidth'] = 0.5

ax.tick_params(axis = 'both', which = 'major', labelsize = 13)
ax.set_ylabel('column index j', size = 13)
ax.set_xlabel('row index i', size = 13)
ax.zaxis.set_rotate_label(False)
ax.set_zlabel(r'$\hat{\beta}_{i,j}$', rotation = 0, size = 15)
plt.savefig('143b.jpg', bbox_inches='tight', dpi = 600)

# %%
xs = np.linspace(1, a+1, a)
ys = np.linspace(1, a+1, a)
xs, ys = np.meshgrid(xs, ys)
zs_surface = clf3.beta.reshape(a,a)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xs, ys, zs_surface, rstride=1, cstride=1, cmap='viridis', edgecolor = 'gray', linewidth = 0.5)

ax.view_init(45, 25)

ax.xaxis.set_major_locator(MultipleLocator(5))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.xaxis._axinfo["grid"]['linestyle'] = ":"
ax.yaxis._axinfo["grid"]['linestyle'] = ":"
ax.zaxis._axinfo["grid"]['linewidth'] = 0.5

ax.tick_params(axis = 'both', which = 'major', labelsize = 13)
ax.set_ylabel('column index j', size = 13)
ax.set_xlabel('row index i', size = 13)
ax.zaxis.set_rotate_label(False)
ax.set_zlabel(r'$\hat{\beta}_{i,j}$', rotation = 0, size = 15)
plt.savefig('143c.jpg', bbox_inches='tight', dpi = 600)
