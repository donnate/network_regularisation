# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from skest import *
import scipy
import time
from signals import *

# %% [markdown]
# #### test codes

# %%
beta_star = smooth_stair(15, 5, 20, 0, 10)[:110]

# %%
plt.plot(beta_star)
print(min(beta_star), max(beta_star))
beta_star.shape
# Out:
# 5.0 20.0
# (110,)

# %%
Psi = toeplitz(0.5, 110)

# %%
D = chain_incidence(110)

# %%
n = 70
p = 110
sigma = 3

# %%
X, y = gauss_sample(n, p, beta_star, Psi, sigma)

# %%
print(naive_cv_large(OUR, X,y, D))
print(naive_cv_large(FL, X,y, D))
print(naive_cv_large(SL, X,y, D))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-2cb66a03bb4b> in <module>
# ----> 1 print(naive_cv_large(OUR, X,y, D))
#       2 print(naive_cv_large(FL, X,y, D))
#       3 print(naive_cv_large(SL, X,y, D))
#
# ~\Desktop\running time\signals.py in naive_cv_large(clf, X, y, D, n_cv)
#      76     gd_sr = GridSearchCV(clf(0,0,D), param_grid=gridlarge,scoring = 'neg_mean_squared_error',cv=n_cv, n_jobs=-1)
#      77     start_time = time.time()
# ---> 78     result = gd_sr.fit(X,y)
#      79     return result.best_params_, time.time() - start_time
#      80
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ...

# %% [markdown]
# ### $l_2$ risk and MSE sometimes do not reflect grouping effect:

# %%
X2, y2 = gauss_sample(n, p, beta_star, Psi, sigma)

# %%
clf2 = FL(2, 30, D).fit(X2, y2)
clf3 = SL(0, 30, D).fit(X2,y2)
clf5 = OUR(25, 20, D).fit(X2,y2)

# %%
plt.plot(clf2.beta)

# %%
plt.plot(clf3.beta)

# %%
plt.plot(clf5.beta)

# %%
plt.scatter(range(1, 111), clf3.beta, s = 7, color = 'red', label = "SL")
plt.plot(range(1, 111), clf3.beta, linewidth = 1, color = "red")
plt.scatter(range(1, 111), clf2.beta, s = 7, color = 'orange', label = "FL")
plt.plot(range(1, 111), clf2.beta, linewidth = 1, color = "orange")
plt.scatter(range(1, 111), clf5.beta, s = 7, color = 'green', label = 'GEN')
plt.plot(range(1, 111), clf5.beta, linewidth = 1, color = "green")
plt.ylabel(r'$\beta^*_j$ value', size = 13)
plt.xlabel(r'$\beta^*$ index $j$', size = 13)
plt.xlim(10, 50)
plt.ylim(4.5, 10.5)
plt.yticks([4.5, 5, 6, 7, 8, 9, 10, 10.5], size = 12)
plt.xticks([10, 20, 30, 40, 50],size = 12)
plt.legend()
plt.tight_layout()
plt.savefig('133a.jpg', bbox_inches='tight', dpi = 600)

# %%
plt.plot(range(1, 111), beta_star, linewidth = 1.5, zorder = -1)
plt.scatter(range(1, 111), beta_star, s = 8, color = "purple")
plt.ylabel(r'$\beta^*_j$ value', size = 13)
plt.xlabel(r'$\beta^*$ index $j$', size = 13)
plt.xlim(10, 50)
plt.ylim(4.5, 10.5)
plt.yticks([4.5, 5, 6, 7, 8, 9, 10, 10.5], size = 12)
plt.xticks([10, 20, 30, 40, 50],size = 12)
plt.tight_layout()
plt.savefig('133b.jpg', bbox_inches='tight', dpi = 600)
